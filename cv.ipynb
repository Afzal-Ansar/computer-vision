# %%
import cv2
import numpy as np
from ultralytics import YOLO

# Centroid Tracker Class
class CentroidTracker:
    def __init__(self, maxDisappeared=30):
        self.nextObjectID = 0
        self.objects = dict()
        self.disappeared = dict()
        self.maxDisappeared = maxDisappeared

    def register(self, centroid):
        self.objects[self.nextObjectID] = centroid
        self.disappeared[self.nextObjectID] = 0
        self.nextObjectID += 1

    def deregister(self, objectID):
        del self.objects[objectID]
        del self.disappeared[objectID]

    def update(self, rects):
        if len(rects) == 0:
            for objectID in list(self.disappeared.keys()):
                self.disappeared[objectID] += 1
                if self.disappeared[objectID] > self.maxDisappeared:
                    self.deregister(objectID)
            return self.objects

        inputCentroids = np.zeros((len(rects), 2), dtype="int")
        for (i, (startX, startY, endX, endY)) in enumerate(rects):
            cX = int((startX + endX) / 2.0)
            cY = int((startY + endY) / 2.0)
            inputCentroids[i] = (cX, cY)

        if len(self.objects) == 0:
            for i in range(0, len(inputCentroids)):
                self.register(inputCentroids[i])
        else:
            objectIDs = list(self.objects.keys())
            objectCentroids = list(self.objects.values())
            D = np.linalg.norm(np.array(objectCentroids)[:, np.newaxis] - inputCentroids, axis=2)
            rows = D.min(axis=1).argsort()
            cols = D.argmin(axis=1)[rows]

            usedRows = set()
            usedCols = set()
            for (row, col) in zip(rows, cols):
                if row in usedRows or col in usedCols:
                    continue
                objectID = objectIDs[row]
                self.objects[objectID] = inputCentroids[col]
                self.disappeared[objectID] = 0
                usedRows.add(row)
                usedCols.add(col)

            unusedRows = set(range(0, D.shape[0])).difference(usedRows)
            unusedCols = set(range(0, D.shape[1])).difference(usedCols)

            if D.shape[0] >= D.shape[1]:
                for row in unusedRows:
                    objectID = objectIDs[row]
                    self.disappeared[objectID] += 1
                    if self.disappeared[objectID] > self.maxDisappeared:
                        self.deregister(objectID)
            else:
                for col in unusedCols:
                    self.register(inputCentroids[col])

        return self.objects

# Load YOLOv8 model
model = YOLO('yolov8n.pt')  # or path to your weights

# Initialize video capture
cap = cv2.VideoCapture(0)  # Use 0 for webcam

tracker = CentroidTracker(maxDisappeared=30)
prev_ids = set()

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv8 detection
    results = model(frame)[0]
    rects = []
    for box in results.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        rects.append((x1, y1, x2, y2))
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)

    # Update tracker
    objects = tracker.update(rects)
    current_ids = set(objects.keys())

    # Detect new and missing objects
    new_ids = current_ids - prev_ids
    missing_ids = prev_ids - current_ids

    for objectID, centroid in objects.items():
        text = f"ID {objectID}"
        color = (0, 255, 0)
        if objectID in new_ids:
            text += " (NEW)"
            color = (0, 255, 255)
        cv2.putText(frame, text, (centroid[0] - 10, centroid[1] - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
        cv2.circle(frame, tuple(centroid), 4, color, -1)

    for objectID in missing_ids:
        print(f"Object ID {objectID} missing!")

    prev_ids = current_ids

    cv2.imshow("Real-Time Object Detection & Tracking", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 255.0ms
# Speed: 9.8ms preprocess, 255.0ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 232.0ms
# Speed: 4.8ms preprocess, 232.0ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 225.1ms
# Speed: 3.9ms preprocess, 225.1ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 235.2ms
# Speed: 4.0ms preprocess, 235.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 239.7ms
# Speed: 4.3ms preprocess, 239.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.9ms
# Speed: 4.1ms preprocess, 222.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.8ms
# Speed: 4.2ms preprocess, 206.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.9ms
# Speed: 4.5ms preprocess, 206.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.4ms
# Speed: 4.8ms preprocess, 214.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.5ms
# Speed: 4.6ms preprocess, 211.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 182.8ms
# Speed: 3.8ms preprocess, 182.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.4ms
# Speed: 2.9ms preprocess, 160.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.2ms
# Speed: 3.3ms preprocess, 160.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.2ms
# Speed: 3.5ms preprocess, 160.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 155.1ms
# Speed: 4.3ms preprocess, 155.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 156.8ms
# Speed: 2.9ms preprocess, 156.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.1ms
# Speed: 3.9ms preprocess, 162.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 143.6ms
# Speed: 4.1ms preprocess, 143.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 145.3ms
# Speed: 3.3ms preprocess, 145.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 158.2ms
# Speed: 4.1ms preprocess, 158.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 182.2ms
# Speed: 3.3ms preprocess, 182.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 195.7ms
# Speed: 4.2ms preprocess, 195.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 178.7ms
# Speed: 4.0ms preprocess, 178.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cell phones, 186.3ms
# Speed: 4.1ms preprocess, 186.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 179.8ms
# Speed: 4.4ms preprocess, 179.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 176.1ms
# Speed: 3.8ms preprocess, 176.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 177.6ms
# Speed: 3.4ms preprocess, 177.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cell phones, 169.1ms
# Speed: 4.3ms preprocess, 169.1ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 177.7ms
# Speed: 4.5ms preprocess, 177.7ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cell phones, 172.3ms
# Speed: 4.1ms preprocess, 172.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 167.6ms
# Speed: 8.1ms preprocess, 167.6ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cell phones, 167.1ms
# Speed: 3.8ms preprocess, 167.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cell phones, 175.7ms
# Speed: 3.6ms preprocess, 175.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cell phones, 189.8ms
# Speed: 4.0ms preprocess, 189.8ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cell phones, 202.6ms
# Speed: 3.4ms preprocess, 202.6ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cell phones, 238.5ms
# Speed: 3.7ms preprocess, 238.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cell phones, 211.0ms
# Speed: 4.2ms preprocess, 211.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 213.6ms
# Speed: 4.4ms preprocess, 213.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 4 cell phones, 217.8ms
# Speed: 3.6ms preprocess, 217.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cell phones, 197.3ms
# Speed: 4.5ms preprocess, 197.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 195.1ms
# Speed: 4.7ms preprocess, 195.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 199.8ms
# Speed: 4.1ms preprocess, 199.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 199.7ms
# Speed: 4.1ms preprocess, 199.7ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cell phones, 204.4ms
# Speed: 3.9ms preprocess, 204.4ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 185.5ms
# Speed: 3.9ms preprocess, 185.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 197.6ms
# Speed: 3.7ms preprocess, 197.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 212.8ms
# Speed: 4.4ms preprocess, 212.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 210.5ms
# Speed: 4.8ms preprocess, 210.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 366.6ms
# Speed: 3.9ms preprocess, 366.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 651.6ms
# Speed: 5.0ms preprocess, 651.6ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 3 cell phones, 335.2ms
# Speed: 9.4ms preprocess, 335.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 280.2ms
# Speed: 4.4ms preprocess, 280.2ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 543.6ms
# Speed: 5.0ms preprocess, 543.6ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 440.8ms
# Speed: 8.7ms preprocess, 440.8ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 399.8ms
# Speed: 6.8ms preprocess, 399.8ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 610.5ms
# Speed: 9.0ms preprocess, 610.5ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 500.7ms
# Speed: 8.3ms preprocess, 500.7ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 237.1ms
# Speed: 5.6ms preprocess, 237.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 253.9ms
# Speed: 4.8ms preprocess, 253.9ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 1 vase, 282.0ms
# Speed: 6.3ms preprocess, 282.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 391.8ms
# Speed: 9.3ms preprocess, 391.8ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 283.4ms
# Speed: 6.8ms preprocess, 283.4ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 349.4ms
# Speed: 10.1ms preprocess, 349.4ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 221.4ms
# Speed: 5.0ms preprocess, 221.4ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 219.2ms
# Speed: 4.4ms preprocess, 219.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.7ms
# Speed: 3.9ms preprocess, 214.7ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.9ms
# Speed: 4.1ms preprocess, 227.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.0ms
# Speed: 4.6ms preprocess, 209.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.3ms
# Speed: 5.3ms preprocess, 215.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.3ms
# Speed: 3.9ms preprocess, 222.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.8ms
# Speed: 3.7ms preprocess, 209.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.4ms
# Speed: 3.9ms preprocess, 210.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.2ms
# Speed: 3.9ms preprocess, 214.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.6ms
# Speed: 4.1ms preprocess, 210.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 229.6ms
# Speed: 4.1ms preprocess, 229.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.3ms
# Speed: 4.2ms preprocess, 219.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 227.0ms
# Speed: 3.9ms preprocess, 227.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.7ms
# Speed: 3.9ms preprocess, 215.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.7ms
# Speed: 4.7ms preprocess, 206.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.8ms
# Speed: 3.9ms preprocess, 222.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 224.2ms
# Speed: 4.2ms preprocess, 224.2ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.0ms
# Speed: 5.4ms preprocess, 220.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Object ID 4 missing!
#
# 0: 480x640 1 person, 230.6ms
# Speed: 3.8ms preprocess, 230.6ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.0ms
# Speed: 4.7ms preprocess, 201.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.5ms
# Speed: 4.0ms preprocess, 196.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.8ms
# Speed: 3.7ms preprocess, 201.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.3ms
# Speed: 4.5ms preprocess, 201.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.1ms
# Speed: 3.9ms preprocess, 209.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.1ms
# Speed: 3.7ms preprocess, 206.1ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.5ms
# Speed: 4.0ms preprocess, 213.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.7ms
# Speed: 3.9ms preprocess, 201.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.8ms
# Speed: 4.7ms preprocess, 197.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.5ms
# Speed: 3.9ms preprocess, 205.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.6ms
# Speed: 4.2ms preprocess, 194.6ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# Object ID 2 missing!
#
# 0: 480x640 1 person, 198.3ms
# Speed: 4.0ms preprocess, 198.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Object ID 1 missing!
#
# 0: 480x640 1 person, 193.1ms
# Speed: 5.1ms preprocess, 193.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Object ID 3 missing!
#
# 0: 480x640 1 person, 207.8ms
# Speed: 4.2ms preprocess, 207.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 217.8ms
# Speed: 3.7ms preprocess, 217.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.1ms
# Speed: 3.8ms preprocess, 218.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 221.3ms
# Speed: 4.0ms preprocess, 221.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 246.0ms
# Speed: 4.4ms preprocess, 246.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.5ms
# Speed: 4.6ms preprocess, 203.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.8ms
# Speed: 4.1ms preprocess, 198.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.9ms
# Speed: 3.7ms preprocess, 207.9ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.1ms
# Speed: 3.4ms preprocess, 209.1ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.7ms
# Speed: 4.0ms preprocess, 202.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.5ms
# Speed: 3.8ms preprocess, 175.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.2ms
# Speed: 3.1ms preprocess, 162.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 157.7ms
# Speed: 4.0ms preprocess, 157.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 229.4ms
# Speed: 3.5ms preprocess, 229.4ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.9ms
# Speed: 3.9ms preprocess, 192.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 159.7ms
# Speed: 3.6ms preprocess, 159.7ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 167.2ms
# Speed: 3.7ms preprocess, 167.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 163.5ms
# Speed: 4.0ms preprocess, 163.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 173.9ms
# Speed: 3.3ms preprocess, 173.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 164.6ms
# Speed: 3.4ms preprocess, 164.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 166.3ms
# Speed: 4.1ms preprocess, 166.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.4ms
# Speed: 3.7ms preprocess, 167.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.7ms
# Speed: 3.7ms preprocess, 161.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cell phones, 168.1ms
# Speed: 3.6ms preprocess, 168.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 150.5ms
# Speed: 3.9ms preprocess, 150.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 171.1ms
# Speed: 5.4ms preprocess, 171.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.7ms
# Speed: 3.8ms preprocess, 168.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.1ms
# Speed: 3.6ms preprocess, 180.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.9ms
# Speed: 3.4ms preprocess, 164.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.0ms
# Speed: 4.6ms preprocess, 167.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.7ms
# Speed: 3.2ms preprocess, 164.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.2ms
# Speed: 3.5ms preprocess, 167.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 170.4ms
# Speed: 3.7ms preprocess, 170.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.1ms
# Speed: 3.4ms preprocess, 162.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 185.8ms
# Speed: 3.5ms preprocess, 185.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.8ms
# Speed: 4.3ms preprocess, 177.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 169.2ms
# Speed: 3.4ms preprocess, 169.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.7ms
# Speed: 4.0ms preprocess, 173.7ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.2ms
# Speed: 3.6ms preprocess, 218.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.2ms
# Speed: 5.1ms preprocess, 192.2ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.4ms
# Speed: 4.4ms preprocess, 196.4ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 199.9ms
# Speed: 3.6ms preprocess, 199.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 177.5ms
# Speed: 3.5ms preprocess, 177.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 183.6ms
# Speed: 3.8ms preprocess, 183.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 175.1ms
# Speed: 3.4ms preprocess, 175.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 183.7ms
# Speed: 3.8ms preprocess, 183.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 184.9ms
# Speed: 3.7ms preprocess, 184.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 skateboard, 1 bottle, 175.1ms
# Speed: 4.0ms preprocess, 175.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 175.8ms
# Speed: 3.8ms preprocess, 175.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 skateboard, 1 cell phone, 172.6ms
# Speed: 3.6ms preprocess, 172.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 187.6ms
# Speed: 3.7ms preprocess, 187.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 182.4ms
# Speed: 3.6ms preprocess, 182.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 188.3ms
# Speed: 3.4ms preprocess, 188.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 182.6ms
# Speed: 3.9ms preprocess, 182.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.3ms
# Speed: 3.5ms preprocess, 181.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 185.8ms
# Speed: 3.6ms preprocess, 185.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.7ms
# Speed: 4.3ms preprocess, 199.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.9ms
# Speed: 3.5ms preprocess, 202.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.7ms
# Speed: 4.6ms preprocess, 211.7ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.3ms
# Speed: 4.3ms preprocess, 214.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.5ms
# Speed: 4.0ms preprocess, 211.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.3ms
# Speed: 4.1ms preprocess, 205.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.9ms
# Speed: 3.9ms preprocess, 206.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.3ms
# Speed: 3.6ms preprocess, 219.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 211.0ms
# Speed: 3.6ms preprocess, 211.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.8ms
# Speed: 4.0ms preprocess, 214.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 205.0ms
# Speed: 3.8ms preprocess, 205.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.5ms
# Speed: 3.7ms preprocess, 202.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.0ms
# Speed: 3.5ms preprocess, 207.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 212.1ms
# Speed: 3.8ms preprocess, 212.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.7ms
# Speed: 3.7ms preprocess, 210.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.0ms
# Speed: 3.9ms preprocess, 196.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.0ms
# Speed: 3.4ms preprocess, 194.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 198.2ms
# Speed: 4.4ms preprocess, 198.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.5ms
# Speed: 4.5ms preprocess, 180.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 185.3ms
# Speed: 3.6ms preprocess, 185.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.0ms
# Speed: 3.8ms preprocess, 183.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.7ms
# Speed: 3.8ms preprocess, 176.7ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.5ms
# Speed: 4.0ms preprocess, 213.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Object ID 7 missing!
#
# 0: 480x640 1 person, 194.6ms
# Speed: 3.9ms preprocess, 194.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.5ms
# Speed: 3.5ms preprocess, 184.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 187.4ms
# Speed: 3.7ms preprocess, 187.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 185.9ms
# Speed: 3.5ms preprocess, 185.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Object ID 6 missing!
#
# 0: 480x640 1 person, 185.1ms
# Speed: 4.6ms preprocess, 185.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Object ID 5 missing!
#
# 0: 480x640 1 person, 186.2ms
# Speed: 3.7ms preprocess, 186.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.8ms
# Speed: 3.7ms preprocess, 195.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.6ms
# Speed: 3.8ms preprocess, 186.6ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.2ms
# Speed: 3.9ms preprocess, 195.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.0ms
# Speed: 3.6ms preprocess, 186.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.5ms
# Speed: 3.8ms preprocess, 192.5ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.0ms
# Speed: 4.3ms preprocess, 200.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 182.2ms
# Speed: 3.9ms preprocess, 182.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.3ms
# Speed: 3.6ms preprocess, 181.3ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.8ms
# Speed: 3.7ms preprocess, 192.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 188.6ms
# Speed: 4.0ms preprocess, 188.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.6ms
# Speed: 4.0ms preprocess, 180.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.0ms
# Speed: 3.8ms preprocess, 181.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.6ms
# Speed: 3.4ms preprocess, 207.6ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.9ms
# Speed: 3.5ms preprocess, 184.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.2ms
# Speed: 3.2ms preprocess, 214.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 219.0ms
# Speed: 5.7ms preprocess, 219.0ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.8ms
# Speed: 3.7ms preprocess, 204.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.1ms
# Speed: 4.2ms preprocess, 208.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.8ms
# Speed: 3.9ms preprocess, 196.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.9ms
# Speed: 3.9ms preprocess, 197.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.0ms
# Speed: 4.8ms preprocess, 197.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 187.8ms
# Speed: 3.6ms preprocess, 187.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.5ms
# Speed: 3.9ms preprocess, 184.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 185.3ms
# Speed: 3.3ms preprocess, 185.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.0ms
# Speed: 3.9ms preprocess, 177.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.4ms
# Speed: 3.9ms preprocess, 177.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 187.1ms
# Speed: 3.6ms preprocess, 187.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.2ms
# Speed: 3.6ms preprocess, 190.2ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.0ms
# Speed: 3.6ms preprocess, 191.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.1ms
# Speed: 4.0ms preprocess, 192.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.6ms
# Speed: 3.5ms preprocess, 183.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.4ms
# Speed: 3.8ms preprocess, 186.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.9ms
# Speed: 3.5ms preprocess, 196.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.4ms
# Speed: 3.7ms preprocess, 194.4ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.7ms
# Speed: 3.6ms preprocess, 196.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 204.9ms
# Speed: 4.0ms preprocess, 204.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.0ms
# Speed: 3.6ms preprocess, 192.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.4ms
# Speed: 3.9ms preprocess, 201.4ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.8ms
# Speed: 4.1ms preprocess, 210.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.0ms
# Speed: 3.6ms preprocess, 206.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.4ms
# Speed: 3.8ms preprocess, 210.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.0ms
# Speed: 3.7ms preprocess, 184.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 229.9ms
# Speed: 4.1ms preprocess, 229.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 222.9ms
# Speed: 3.7ms preprocess, 222.9ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 218.6ms
# Speed: 4.0ms preprocess, 218.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 223.3ms
# Speed: 3.4ms preprocess, 223.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.9ms
# Speed: 3.9ms preprocess, 208.9ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.0ms
# Speed: 3.8ms preprocess, 199.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 201.6ms
# Speed: 3.8ms preprocess, 201.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.8ms
# Speed: 4.2ms preprocess, 190.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.6ms
# Speed: 3.7ms preprocess, 199.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.9ms
# Speed: 4.1ms preprocess, 194.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.0ms
# Speed: 3.7ms preprocess, 193.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.9ms
# Speed: 3.6ms preprocess, 196.9ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 187.5ms
# Speed: 3.7ms preprocess, 187.5ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.8ms
# Speed: 3.7ms preprocess, 200.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.1ms
# Speed: 4.1ms preprocess, 203.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.8ms
# Speed: 3.5ms preprocess, 195.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 195.7ms
# Speed: 3.5ms preprocess, 195.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 188.7ms
# Speed: 3.5ms preprocess, 188.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.4ms
# Speed: 3.7ms preprocess, 200.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.1ms
# Speed: 3.6ms preprocess, 197.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.7ms
# Speed: 3.6ms preprocess, 193.7ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.5ms
# Speed: 3.9ms preprocess, 179.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.0ms
# Speed: 3.3ms preprocess, 190.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 230.5ms
# Speed: 5.5ms preprocess, 230.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 220.2ms
# Speed: 4.4ms preprocess, 220.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Object ID 8 missing!
#
# 0: 480x640 1 person, 193.9ms
# Speed: 3.8ms preprocess, 193.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.0ms
# Speed: 3.7ms preprocess, 190.0ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 177.0ms
# Speed: 4.4ms preprocess, 177.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.0ms
# Speed: 3.6ms preprocess, 184.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 185.7ms
# Speed: 3.4ms preprocess, 185.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.1ms
# Speed: 3.9ms preprocess, 176.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 174.9ms
# Speed: 3.7ms preprocess, 174.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 159.5ms
# Speed: 3.5ms preprocess, 159.5ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.8ms
# Speed: 4.1ms preprocess, 173.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.6ms
# Speed: 3.6ms preprocess, 202.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
